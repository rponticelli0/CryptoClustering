# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="f9f059ac-68a6-49cb-8e69-9ebe2896b2ba" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
scaler = StandardScaler()
df_market_data_scaled = scaler.fit_transform(df_market_data)

# %%
# Create a DataFrame with the scaled data
# Copy the crypto names from the original DataFrame
# Set the coin_id column as index
df_scaled = pd.DataFrame(
    df_market_data_scaled, 
    columns=df_market_data.columns, 
    index=df_market_data.index
)

# Display the scaled DataFrame
df_scaled.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values from 1 to 11
# Create an empty list to store the inertia values
# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_scaled`
# 3. Append the model.inertia_ to the inertia list
inertia = []
k_values = range(1, 12)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=1)
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)

elbow_data = {"k": k_values, "inertia": inertia}
elbow_df = pd.DataFrame(elbow_data)

# %%
# Create a dictionary with the data to plot the Elbow curve
# Create a DataFrame with the data to plot the Elbow curve
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
elbow_df.hvplot.line(x="k", y="inertia", title="Elbow Curve", xlabel="k", ylabel="Inertia")
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** 4

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled DataFrame

# %%
# Initialize the K-Means model using the best value for k
best_k = 4

# %%
# Fit the K-Means model using the scaled DataFrame
kmeans = KMeans(n_clusters=best_k, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled DataFrame
df_scaled['Cluster'] = kmeans.fit_predict(df_scaled)

# Print the resulting array of cluster values.
df_scaled.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a copy of the scaled DataFrame
df_scaled_copy = df_scaled.copy()

# %%
# Add a new column to the copy of the scaled DataFrame with the predicted clusters
df_scaled_copy['Cluster'] = kmeans.labels_

# Display the copy of the scaled DataFrame
df_scaled_copy.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using hvPlot by setting
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
# Ensure coin_id is available for hover
df_scaled_copy["coin_id"] = df_market_data.index

df_scaled_copy.hvplot.scatter(
    x="price_change_percentage_24h", 
    y="price_change_percentage_7d", 
    by="Cluster", 
    hover_cols=["coin_id"], 
    title="Cryptocurrency Clusters"
)
# Out:
# :NdOverlay   [Cluster]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce the original scaled DataFrame
# down to three principal components.
pca_data = pca.fit_transform(df_scaled.drop("Cluster", axis=1))

pca_df = pd.DataFrame(pca_data, columns=["PC1", "PC2", "PC3"], index=df_scaled.index)

# View the scaled PCA data
pca_df.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %%
# Retrieve the explained variance to determine how much information
# can be attributed to each principal component.
explained_variance = pca.explained_variance_ratio_.sum()
print(f'Total explained variance: {explained_variance:.2f}')
# Out:
# Total explained variance: 0.90

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** 0.90

# %%
# Create a new DataFrame with the PCA data.
pca_df = pd.DataFrame(

# Copy the crypto names from the original scaled DataFrame
pca_data,  # This is the output from PCA
    columns=["PC1", "PC2", "PC3"], 
    index=df_market_data.index  # Use the original index (coin_id)
)

# Display the scaled PCA DataFrame
pca_df.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Scaled PCA DataFrame

# %%
# Initialize an empty list to store inertia values
inertia_pca = []

# Create a list with the number of k-values from 1 to 11
k_values = range(1, 12)

# %%
# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_pca`
# 3. Append the model.inertia_ to the inertia list
for k in k_values:
    kmeans_pca = KMeans(n_clusters=k, random_state=1)
    kmeans_pca.fit(pca_df)
    inertia_pca.append(kmeans_pca.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data_pca = {"k": k_values, "inertia": inertia_pca}

# Create a DataFrame with the data to plot the Elbow curve
elbow_df_pca = pd.DataFrame(elbow_data_pca)

# Display the Elbow DataFrame
elbow_df_pca.head()
# Out:
#    k     inertia
# 0  1  256.874086
# 1  2  182.339530
# 2  3  135.442408
# 3  4   49.665497
# 4  5   38.672582

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
elbow_df_pca.hvplot.line(
    x="k", y="inertia", 
    title="Elbow Curve (PCA Data)", 
    xlabel="Number of clusters (k)", 
    ylabel="Inertia"
)
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** 0

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Scaled PCA DataFrame

# %%
# Define the best value for k (replace <best_k> with the optimal value you identified)
best_k_pca = <best_k>  # Replace with the actual value

# Initialize the K-Means model with the optimal number of clusters
kmeans_pca = KMeans(n_clusters=best_k_pca, random_state=1)

# %%
# Fit the K-Means model using the PCA data
kmeans_pca.fit(pca_df)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled PCA DataFrame
pca_df['Cluster'] = kmeans_pca.labels_

# Print the resulting array of cluster values.
pca_df.head()
# Out:
#                    PC1       PC2       PC3  Cluster
# coin_id
# bitcoin      -0.600667  0.842760  0.461595       10
# ethereum     -0.458261  0.458466  0.952877       10
# tether       -0.433070 -0.168126 -0.641752        5
# ripple       -0.471835 -0.222660 -0.479053        5
# bitcoin-cash -1.157800  2.041209  1.859715        7

# %%
# Create a copy of the scaled PCA DataFrame
pca_df_copy = pca_df.copy()

# Add a new column to the copy of the PCA DataFrame with the predicted clusters
pca_df_copy["Cluster"] = kmeans_pca.labels_

# Display the copy of the scaled PCA DataFrame
pca_df_copy.head()
# Out:
#                    PC1       PC2       PC3  Cluster
# coin_id
# bitcoin      -0.600667  0.842760  0.461595       10
# ethereum     -0.458261  0.458466  0.952877       10
# tether       -0.433070 -0.168126 -0.641752        5
# ripple       -0.471835 -0.222660 -0.479053        5
# bitcoin-cash -1.157800  2.041209  1.859715        7

# %%
# Ensure the 'coin_id' column is available for hover
pca_df_copy["coin_id"] = pca_df_copy.index

# Create the scatter plot using hvPlot
pca_df_copy.hvplot.scatter(
    x="PC1", 
    y="PC2", 
    by="Cluster",  # Color points based on clusters
    hover_cols=["coin_id"],  # Display crypto name on hover
    title="Cryptocurrency Clusters (PCA)",
    width=800,
    height=400
)
# Out:
# :NdOverlay   [Cluster]
#    :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves
elbow_original = elbow_df.hvplot.line(
    x="k", y="inertia", title="Elbow Curve (Original Data)", xlabel="k", ylabel="Inertia"
)

elbow_pca = elbow_df_pca.hvplot.line(
    x="k", y="inertia", title="Elbow Curve (PCA Data)", xlabel="k", ylabel="Inertia"
)

# Display the composite plot
elbow_original + elbow_pca
# Out:
# :Layout
#    .Curve.I  :Curve   [k]   (inertia)
#    .Curve.II :Curve   [k]   (inertia)

# %%
# Scatter plot with original data clusters
original_clusters = df_scaled_copy.hvplot.scatter(
    x="price_change_percentage_24h", 
    y="price_change_percentage_7d", 
    by="Cluster", 
    hover_cols=["coin_id"], 
    title="Clusters (Original Data)"
)

# Scatter plot with PCA data clusters
pca_clusters = pca_df_copy.hvplot.scatter(
    x="PC1", 
    y="PC2", 
    by="Cluster", 
    hover_cols=["coin_id"], 
    title="Clusters (PCA Data)"
)

# Display the composite plot
original_clusters + pca_clusters
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [Cluster]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [Cluster]
#       :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** Using PCA reduces the dimensionality of the dataset, which simplifies the clustering process. This often leads to:
#
#         - Better-defined clusters: Clusters might become more distinct, especially when the original data contains noisy or redundant features.
#         - Improved performance: Fewer features reduce computational complexity, making clustering faster.
#         - Potential information loss: If the explained variance of the PCA components is too low, some meaningful patterns might be lost, which could affect clustering accuracy.
